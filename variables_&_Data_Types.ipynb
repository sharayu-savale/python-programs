# %% [markdown]
# <a href="https://colab.research.google.com/github/sharayu-savale/python-programs/blob/main/variables_%26_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("sharayu is my name.\n my age is 20.")
# Out:
# sharayu is my name.
#  my age is 20.

# %%
a=("sharayu is my name. " )
b=("my age is 20")
print(a+" "+b)
# Out:
# sharayu is my name.  my age is 20

# %%
print(43+43)
# Out:
# 86

# %%
print("43+43")
# Out:
# 43+43

# %%
name = "sharayu"
print(name)
# Out:
# sharayu

# %%
name = "sharayu"
name ="ram"
print(name)
# Out:
# ram

# %%
name = ("sharayu")
age = 20
price = 456.54
name1 = 'c'
print(type(name))
print(type(age))
print(type(price))
print(type(name1))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
age = 23
old = False
a = None
print(type(age))
print(type(old))
print(type(a))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
a = int (input("enter number:"))
b = int (input("enter number:"))
sum =a+b
print(sum)
# Out:
# enter number:40
# enter number:30
# 70

# %%
# **=power
a = 2
b = 8
print(a**b)
print((a==b) or (a>b))
# Out:
# 256
# False

# %%
#type conversion
a = 2
b = 2.5
print("sum :",a+b)
# Out:
# sum : 4.5

# %%
a = int(input("enter number:"))
b = int(input("enter number:"))
print("sum:",a+b)
# Out:
# enter number:34
# enter number:54
# sum: 88

# %%
# type casting
a = 2
b = 2.5
c = int(b)
print("sum :",a+c)
# Out:
# sum : 4

# %%
a = 2
b = int(2.5)

print("sum :",a+b)
# Out:
# sum : 4

# %%
name = input("enter name")
print(type(name))
# Out:
# enter namesharayu
# <class 'str'>

# %%
value = int(input("enter value"))
print(type(value))
# Out:
# enter value56
# <class 'int'>

# %%
value = (input("enter value"))
print(type(value))
# Out:
# enter value56
# <class 'str'>

# %%
# area of a square
side = int(input("enter side :"))
area =side * side
print("area of a square:",area)
# Out:
# enter side :12
# area of a square: 144

# %%
a =float(input("enter number:"))
b =float(input("enter number:"))
avg =(a+b)/2
print("avarage:",avg)
# Out:
# enter number:5
# enter number:3
# avarage: 4.0

# %%
a = int(input("enter number"))
b = int(input("enter number"))

print(a >= b )
# Out:
# enter number45
# enter number34
# True

# %%
a = int(input("enter number"))
b = int(input("enter number"))

print(a >= b )
# Out:
# enter number34
# enter number45
# False
