# %% [markdown]
# <a href="https://colab.research.google.com/github/sharayu-savale/python-programs/blob/main/strings_%26_conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "This is a string"
str2 = 'sharayusavale'
str3 = """ Hieee """
print(str1)
print(str2)
print(str3)
# Out:
# This is a string
# sharayusavale
#  Hieee

# %%
str1 ="this is a string \n sharayusavale \n hieee"
print(str1)
# Out:
# this is a string
#  sharayusavale
#  hieee

# %%
str1 ="this is a string. \t sharayusavale .\t hieee."
print(str1)
# Out:
# this is a string. 	 sharayusavale .	 hieee.

# %% [markdown]
# concatenation

# %%
str1 ='hello'
str2 ='world'
print(str1 + " " +str2)
# Out:
# hello world

# %%
str1 = "my name is sharayu"
print(len(str1))
# Out:
# 18

# %%
str1 = "d"
print(len(str1))
# Out:
# 1

# %%
str1 ='hello'
str2 ='world'
final_string =(str1 + " " +str2)
print(final_string)
print(len(final_string))
# Out:
# hello world
# 11

# %%
str1="hello world"
print(str1[2])
# Out:
# l

# %%
print(str1[1:5])
# Out:
# ello

# %%
print(str1[4:7])
# Out:
# o w

# %%
print(str1[-5:-3])
# Out:
# wo

# %%
print(str1[-8:-1])
# Out:
# lo worl

# %%
print(str1[:])
# Out:
# hello world

# %%
str = "i am studying python from Apnacollege"
print(str.endswith("ing"))
# Out:
# False

# %%
print(str.endswith("ege"))
# Out:
# True

# %%
str = "i am studying python from Apnacollege"
print(str.capitalize())
# Out:
# I am studying python from apnacollege

# %%
print(str.title())
# Out:
# I Am Studying Python From Apnacollege

# %%
str = "i am studying python from Apnacollege"
print(str.replace("a","o"))
# Out:
# i om studying python from Apnocollege

# %%
print(str.replace("python","javascript"))
# Out:
# i am studying javascript from Apnacollege

# %%
str = "i am studying python from Apnacollege"
print(str.find("a"))
# Out:
# 2

# %%
print(str.find("python"))
# Out:
# 14

# %%
print(str.find("z"))
# Out:
# -1

# %%
print(str.count("a"))
# Out:
# 2

# %%
a=input("enter your name:")
print(len(a))
# Out:
# enter your name:sharayusavale
# 13

# %%
str1 ="uydtdryd$x$yftf$"
print(str1.count("$"))
# Out:
# 3

# %%
age = int(input("enter your age:"))
if(age<18):
    print("not eligible for licence ")
else:
    print("eligible for licence ")
# Out:
# enter your age:45
# eligible for licence

# %%
marks = int (input("enter your marks:"))
if(marks>=90):
    print("grade A")
elif((marks<=90)and(marks>=80)):
      print("grade B")
elif((marks<=80)and(marks>=70)):
      print("grade C")

elif((marks<70)):
      print("grade D")
else:
    print("invalid marks")
# Out:
# enter your marks:75
# grade C

# %%
age = int(input("enter your age:"))
 #nesting
if(age >=18):
    if(age >=80):
      print("cannot drive")
    else:
      print("can drive")
else:
    print("cannot drive")
# Out:
# enter your age77
# can drive

# %%
number = int(input("enter number:"))
if(number % 2 == 0):
    print("number is even")
else:
      print("number is odd")
# Out:
# enter number:64
# number is even

# %%
a = int(input("enter number:"))
b = int(input("enter number:"))
c = int(input("enter number:"))
if((a>c)and(a>b)):
     print("a is greater")
elif("b<c"):
    print("c is greater")
else:
      print("b is greater")
# Out:
# enter number:56
# enter number:43
# enter number:67
# c is greater

# %%
num = int(input("enter number:"))
if(num % 7 == 0):
    print("multiple of 7")
else:
    print(" not multiple of 7")
# Out:
# enter number:49
# multiple of 7
